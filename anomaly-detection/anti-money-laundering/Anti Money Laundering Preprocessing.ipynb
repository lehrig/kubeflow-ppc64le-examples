# %% [markdown]
# # AML Use Case

# %%
# !pip install alibi
# Out:
# Collecting alibi
#   Downloading alibi-0.9.0-py3-none-any.whl (522 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 523.0/523.0 kB 7.7 MB/s eta 0:00:00a 0:00:01
# Collecting spacy[lookups]<4.0.0,>=2.0.0
#   Downloading spacy-3.5.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.5 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (2.28.1)
# Requirement already satisfied: Pillow<10.0,>=5.4.1 in /opt/conda/lib/python3.8/site-packages (from alibi) (9.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.2 in /opt/conda/lib/python3.8/site-packages (from alibi) (1.23.4)
# Requirement already satisfied: attrs<23.0.0,>=19.2.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from alibi) (4.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.7.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (4.24.0)
# Requirement already satisfied: dill<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (0.3.6)
# Requirement already satisfied: scikit-image<0.20,>=0.17.2 in /opt/conda/lib/python3.8/site-packages (from alibi) (0.19.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (3.5.3)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (1.9.3)
# Requirement already satisfied: pandas<2.0.0,>=0.23.3 in /opt/conda/lib/python3.8/site-packages (from alibi) (1.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.28.1 in /opt/conda/lib/python3.8/site-packages (from alibi) (4.64.1)
# Collecting blis<0.8.0
#   Using cached blis-0.7.9-cp38-cp38-linux_ppc64le.whl
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from alibi) (1.1.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas<2.0.0,>=0.23.3->alibi) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.21.0->alibi) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.21.0->alibi) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.21.0->alibi) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.21.0->alibi) (1.26.12)
# Requirement already satisfied: networkx>=2.2 in /opt/conda/lib/python3.8/site-packages (from scikit-image<0.20,>=0.17.2->alibi) (2.8.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.8/site-packages (from scikit-image<0.20,>=0.17.2->alibi) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.8/site-packages (from scikit-image<0.20,>=0.17.2->alibi) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in /opt/conda/lib/python3.8/site-packages (from scikit-image<0.20,>=0.17.2->alibi) (2.19.3)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=1.0.0->alibi) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=1.0.0->alibi) (2.2.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy[lookups]<4.0.0,>=2.0.0->alibi) (0.7.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy[lookups]<4.0.0,>=2.0.0->alibi) (63.4.1)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.0 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.9-cp38-cp38-linux_ppc64le.whl
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.6-cp38-cp38-linux_ppc64le.whl
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.8-cp38-cp38-linux_ppc64le.whl
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy[lookups]<4.0.0,>=2.0.0->alibi) (3.1.2)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 10.0 MB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.7-cp38-cp38-linux_ppc64le.whl
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/conda/lib/python3.8/site-packages (from spacy[lookups]<4.0.0,>=2.0.0->alibi) (1.10.2)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.8-cp38-cp38-linux_ppc64le.whl
# Collecting spacy-lookups-data<1.1.0,>=1.0.3
#   Downloading spacy_lookups_data-1.0.3-py2.py3-none-any.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 9.3 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from transformers<5.0.0,>=4.7.0->alibi) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /opt/conda/lib/python3.8/site-packages/huggingface_hub-0.11.0-py3.8.egg (from transformers<5.0.0,>=4.7.0->alibi) (0.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.8/site-packages (from transformers<5.0.0,>=4.7.0->alibi) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.8/site-packages (from transformers<5.0.0,>=4.7.0->alibi) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.8/site-packages (from transformers<5.0.0,>=4.7.0->alibi) (0.11.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.0->alibi) (1.16.0)
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy[lookups]<4.0.0,>=2.0.0->alibi) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy[lookups]<4.0.0,>=2.0.0->alibi) (2.1.1)
# Building wheels for collected packages: spacy
#   Building wheel for spacy (pyproject.toml) ... done
#   Created wheel for spacy: filename=spacy-3.5.0-cp38-cp38-linux_ppc64le.whl size=32489095 sha256=87f8d0fd977e86ed17c41c76ba8485c6306bc85a4d872401e998f0b4cf7f8be9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d8/2d/4b/e16165bbdc258b86689cf2f56f86eb9be4291d418f8a0ff1cc
# Successfully built spacy
# Installing collected packages: cymem, wasabi, spacy-lookups-data, spacy-loggers, spacy-legacy, smart-open, murmurhash, langcodes, catalogue, blis, srsly, preshed, pathy, confection, thinc, spacy, alibi
# Successfully installed alibi-0.9.0 blis-0.7.9 catalogue-2.0.8 confection-0.0.4 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.1 preshed-3.0.8 smart-open-6.3.0 spacy-3.5.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 spacy-lookups-data-1.0.3 srsly-2.4.6 thinc-8.1.8 wasabi-1.1.1

# %%
## data from https://github.com/IBM/AML-Data
## !wget https://ibm.box.com/shared/static/gu098ispc0by71ubfm1px111n807xk53.csv

# %% [markdown]
# ## Import Data From CSV

# %%
from datetime import datetime

dtypes = {
    'From Bank': str,
    'Account': str,
    'To Bank': str,
    'Account.1': str,
    'Amount Received': str,
    'Receiving Currency': str,
    'Amount Paid': str,
    'Payment Currency': str,
    'Payment Format': str,
    'Is Laundering': int,
}

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder 

data = pd.DataFrame()
oenc = OrdinalEncoder()

for chunk in pd.read_csv('ibm-aml-data-2.csv', chunksize=100_000, nrows=1_000_000, dtype=dtypes, parse_dates=['Timestamp'], index_col=0):
    data = pd.concat([data, chunk])

data.replace('(null)', pd.NA, inplace=True)
data.dropna(inplace=True)
data.sort_values('Timestamp', inplace=True)
data['Amount Paid'] = data['Amount Paid'].astype(float)
data['Amount Received'] = data['Amount Received'].astype(float)
data = data.set_index('Timestamp')
data.iloc[:, [0,1,2,3,5,7,8]] = oenc.fit_transform(data.iloc[:, [0,1,2,3,5,7,8]])
cols = list(data.columns)
cols.pop(cols.index('Is Laundering'))
data = data[['Is Laundering']+cols]
data.head()
len(data)
# Out:
# 1000000

# %%
data.head()
# Out:
#             Is Laundering  From Bank   Account  To Bank  Account.1  \
# Timestamp
# 2019-01-01              0    10780.0  187014.0  10552.0   187940.0
# 2019-01-01              0    35786.0  588375.0  35845.0   616655.0
# 2019-01-01              0     8376.0  406686.0    254.0    68406.0
# 2019-01-01              0      686.0  406687.0  20959.0   377791.0
# 2019-01-01              0     4019.0  396610.0   6098.0   345197.0
#
#             Amount Received  Receiving Currency  Amount Paid  \
# Timestamp
# 2019-01-01       164.760000                 7.0   164.760000
# 2019-01-01         0.011102                 1.0     0.011102
# 2019-01-01         9.180000                12.0     9.180000
# 2019-01-01        48.290000                12.0    48.290000
# 2019-01-01         8.740000                 4.0     8.740000
#
#             Payment Currency  Payment Format
# Timestamp
# 2019-01-01               7.0             4.0
# 2019-01-01               1.0             4.0
# 2019-01-01              12.0             4.0
# 2019-01-01              12.0             4.0
# 2019-01-01               4.0             4.0

# %%
from pickle import dump, load
dump(oenc, open('ordinal_encoder.pkl', 'wb'))
scaler = load(open('ordinal_encoder.pkl', 'rb'))

# %% [markdown]
# ## Create Graph From Transactions

# %%
# inspired by:
# https://www.emerald.com/insight/content/doi/10.1108/JMLC-07-2019-0055/full/pdf?title=detecting-money-laundering-transactions-with-machine-learning

# %%
import networkx as nx

source = data['From Bank']+data['Account']
target = data['To Bank']+data['Account.1']

trans_graph = nx.DiGraph()
trans_graph.add_edges_from(list(zip(source, target)))

print('#Accounts:', len(trans_graph.nodes))
print('#Transactions:', sum(data.duplicated(subset=['Account', 'Account.1']))+len(trans_graph.edges))
print('#Connections:', len(trans_graph.edges))
# Out:
# #Accounts: 565715
# #Transactions: 998673
# #Connections: 944231

# %% [markdown]
# ### Calculate Graph Features

# %%
cc = nx.clustering(trans_graph, weight=None)
ids = trans_graph.in_degree()
ods = trans_graph.out_degree()
dc = nx.degree_centrality(trans_graph)

# %% [raw]
# data['Clustering Coeff From'] = source.map(cc)
# data['Clustering Coeff To'] = target.map(cc)
# data['In Degree From'] = source.map(ids)
# data['In Degree To'] = target.map(ids)
# data['Out Degree From'] = source.map(ods)
# data['Out Degree To'] = target.map(ods)
# data['Degree Centrality From'] = source.map(dc)
# data['Degree Centrality To'] = target.map(dc)

# %%
data['Clustering Coeff'] = source.map(cc) + target.map(cc)
data['In Degree'] = source.map(ids) + target.map(ids)
data['Out Degree'] = source.map(ods) + target.map(ods)
data['Degree Centrality'] = source.map(dc) + target.map(dc)

# %%
from scipy.stats import zscore

transaction_history = (source + target).value_counts().to_dict()
data['No. of Past Transactions'] = (source+target).map(transaction_history)
data['Z-Score Diff'] = zscore(data['Amount Paid'])
data.head()
# Out:
#             Is Laundering  From Bank   Account  To Bank  Account.1  \
# Timestamp
# 2019-01-01              0    10780.0  187014.0  10552.0   187940.0
# 2019-01-01              0    35786.0  588375.0  35845.0   616655.0
# 2019-01-01              0     8376.0  406686.0    254.0    68406.0
# 2019-01-01              0      686.0  406687.0  20959.0   377791.0
# 2019-01-01              0     4019.0  396610.0   6098.0   345197.0
#
#             Amount Received  Receiving Currency  Amount Paid  \
# Timestamp
# 2019-01-01       164.760000                 7.0   164.760000
# 2019-01-01         0.011102                 1.0     0.011102
# 2019-01-01         9.180000                12.0     9.180000
# 2019-01-01        48.290000                12.0    48.290000
# 2019-01-01         8.740000                 4.0     8.740000
#
#             Payment Currency  Payment Format  Clustering Coeff  In Degree  \
# Timestamp
# 2019-01-01               7.0             4.0               0.0          3
# 2019-01-01               1.0             4.0               0.0          5
# 2019-01-01              12.0             4.0               0.0          2
# 2019-01-01              12.0             4.0               0.0          1
# 2019-01-01               4.0             4.0               0.0          3
#
#             Out Degree  Degree Centrality  No. of Past Transactions  \
# Timestamp
# 2019-01-01          12           0.000027                         2
# 2019-01-01           4           0.000016                         1
# 2019-01-01           6           0.000014                         2
# 2019-01-01           6           0.000012                         1
# 2019-01-01           3           0.000011                         1
#
#             Z-Score Diff
# Timestamp
# 2019-01-01     -0.017984
# 2019-01-01     -0.018104
# 2019-01-01     -0.018097
# 2019-01-01     -0.018069
# 2019-01-01     -0.018098

# %% [markdown]
# ## Reduce Memory Usage of the DataFrame

# %%
import numpy as np

def reduce_mem_usage(props):
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print(f"Memory usage of dataframe: {start_mem_usg} MB")
    for col in props.columns:
        if props[col].dtype != object:
            
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()

            if not np.isfinite(props[col]).all(): 
                props[col].fillna(mn-1,inplace=True)  
                   
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True

            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    
            
            else:
                props[col] = props[col].astype(np.float32)
    
    mem_usg = props.memory_usage().sum() / 1024**2 
    print(f"MEMORY USAGE AFTER COMPLETION: {mem_usg} MB")
    print(f"{100*mem_usg/start_mem_usg}% of the initial size")
    return props

# %%
data = reduce_mem_usage(data)
# Out:
# Memory usage of dataframe: 129.69970703125 MB
# MEMORY USAGE AFTER COMPLETION: 44.82269287109375 MB
# 34.55882352941177% of the initial size

# %%
data.to_csv('AMLdata_features_graph.csv')

# %%
df = pd.read_csv('AMLdata_features_graph.csv', nrows=2, index_col=0)
df.head()
# Out:
#             Is Laundering  From Bank  Account  To Bank  Account.1  \
# Timestamp
# 2019-01-01              0      10780   187014    10552     187940
# 2019-01-01              0      35786   588375    35845     616655
#
#             Amount Received  Receiving Currency  Amount Paid  \
# Timestamp
# 2019-01-01       164.760000                   7   164.760000
# 2019-01-01         0.011102                   1     0.011102
#
#             Payment Currency  Payment Format  Clustering Coeff  In Degree  \
# Timestamp
# 2019-01-01                 7               4               0.0          3
# 2019-01-01                 1               4               0.0          5
#
#             Out Degree  Degree Centrality  No. of Past Transactions  \
# Timestamp
# 2019-01-01          12           0.000027                         2
# 2019-01-01           4           0.000016                         1
#
#             Z-Score Diff
# Timestamp
# 2019-01-01     -0.017984
# 2019-01-01     -0.018104

# %% [markdown]
# > upload to box and create shared link, so that you can get the data via wget onto the server

# %%
sql = 'CREATE TABLE IF NOT EXISTS public.transactions('
for (a, b) in zip(data.columns, data.dtypes):
    b = "bigint" if "int" in str(b) else "real"
    sql += f' "{a}" {b},'
    
sql = sql[:-1]
sql += ');'
sql
# Out:
# 'CREATE TABLE IF NOT EXISTS public.transactions( "Is Laundering" bigint, "From Bank" bigint, "Account" bigint, "To Bank" bigint, "Account.1" bigint, "Amount Received" real, "Receiving Currency" bigint, "Amount Paid" real, "Payment Currency" bigint, "Payment Format" bigint, "Clustering Coeff" real, "In Degree" bigint, "Out Degree" bigint, "Degree Centrality" real, "No. of Past Transactions" bigint, "Z-Score Diff" real);'

# %% [markdown]
# ```
# POSTGRES_POD=$(oc get po -l name=postgresql -o jsonpath="{.items[0].metadata.name}")
#
# oc port-forward ${POSTGRES_POD} 5433:5432
#
# DATA_FILE=AMLdata_features_graph.csv
# wget <shared_box_link> -O $DATA_FILE
# sed -i 's/\$//g' $DATA_FILE
# cat > init-transactions.sql <<EOF
# CREATE TABLE IF NOT EXISTS public.laundering_transactions
# (
#     "Date" date,
#     "Is Laundering" bigint,
#     "From Bank" bigint,
#     "Account" bigint,
#     "To Bank" bigint,
#     "Account.1" bigint,
#     "Amount Received" real,
#     "Receiving Currency" bigint,
#     "Amount Paid" real,
#     "Payment Currency" bigint,
#     "Payment Format" bigint,
#     "Clustering Coeff" real,
#     "In Degree" bigint,
#     "Out Degree" bigint,
#     "Degree Centrality" real,
#     "No. of Past Transactions" bigint,
#     "Z-Score Diff" real
# );
#
# \copy public.laundering_transactions FROM '$DATA_FILE' WITH (FORMAT csv, HEADER true, DELIMITER ',');
# EOF
# psql -h 127.0.0.1 -p 5433 -U admin -d stock-prices -a -f init-transactions.sql
# ```
